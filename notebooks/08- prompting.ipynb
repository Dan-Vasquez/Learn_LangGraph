# %%
from langchain_core.prompts import PromptTemplate

template = """\
    # intrucciones para el Asistente de AI

    Recuerda que hoy es {fecha_actual}

    ## Rol
    Eres un experto en marketing digital con 10 años de experiencia.

    ## Tareas
    Analiza el siguiente texto de un anuncio y proporciona 3 sugerencias para mejorarlo, enfocandote en el llamado a la accion

    ## Texto del Anuncio
    {texto_anuncio}

    ## Formato de Salida
    - *Sugerencia 1:* [Tu sugerencia 1]
    - *Sugerencia 2:* [Tu sugerencia 2]
    - *Sugerencia 2:* [Tu sugerencia 3]
    """

prompt_template = PromptTemplate.from_template(template)
prompt = prompt_template.format(fecha_actual="2026-02-05", texto_anuncio="Este es un anuncio de prueba")
print(prompt)
# Out:
#     # intrucciones para el Asistente de AI
#
#     Recuerda que hoy es 2026-02-05
#
#     ## Rol
#     Eres un experto en marketing digital con 10 años de experiencia.
#
#     ## Tareas
#     Analiza el siguiente texto de un anuncio y proporciona 3 sugerencias para mejorarlo, enfocandote en el llamado a la accion
#
#     ## Texto del Anuncio
#     Este es un anuncio de prueba
#
#     ## Formato de Salida
#     - *Sugerencia 1:* [Tu sugerencia 1]
#     - *Sugerencia 2:* [Tu sugerencia 2]
#     - *Sugerencia 2:* [Tu sugerencia 3]

# %%
from datetime import datetime

today = datetime.now().strftime("%Y-%m-%d")

prompt_template = PromptTemplate.from_template(template,  partial_variables={"fecha_actual":today})
prompt = prompt_template.format(texto_anuncio="Este es un anuncio de prueba")
print(prompt)
# Out:
#     # intrucciones para el Asistente de AI
#
#     Recuerda que hoy es 2026-02-05
#
#     ## Rol
#     Eres un experto en marketing digital con 10 años de experiencia.
#
#     ## Tareas
#     Analiza el siguiente texto de un anuncio y proporciona 3 sugerencias para mejorarlo, enfocandote en el llamado a la accion
#
#     ## Texto del Anuncio
#     Este es un anuncio de prueba
#
#     ## Formato de Salida
#     - *Sugerencia 1:* [Tu sugerencia 1]
#     - *Sugerencia 2:* [Tu sugerencia 2]
#     - *Sugerencia 2:* [Tu sugerencia 3]

# %%
template = """
You are a helpful that responds to the user's message

{% if name %}
The user's name is {{ name }} and you can call them by that name
{% endif %}

The user's message is: {{ user_message }}
"""

prompt_template = PromptTemplate.from_template(template, template_format="jinja2")
prompt = prompt_template.format(user_message="Como puedo mejorar mi sitio web?", name="")
print(prompt)
