# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model

llm = init_chat_model("openai:gpt-4.1-nano", temperature=0.3)

# %%
openai_vector_store_ids=[
    "vs_6983a1c1d9c0819184ebc8913c325aa8"
]

file_search_tool={
    "type": "file_search",
    "vector_store_ids": openai_vector_store_ids
}

llm_with_tools = llm.bind_tools([file_search_tool])

# %%
response = llm_with_tools.invoke("Como mejoro el rendimiento de mi website")
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# [{'id': 'fs_01f2f359b6466553006983a30b59648194bd9a7c86ca7acd75', 'queries': ['Cómo mejorar el rendimiento de un website'], 'status': 'completed', 'type': 'file_search_call'}, {'type': 'text', 'text': 'Para mejorar el rendimiento de tu website, puedes seguir varias prácticas recomendadas que incluyen optimizar imágenes, eliminar recursos que bloquean el renderizado, servir imágenes en formatos de próxima generación, minificar JavaScript y diferir CSS no utilizado. Además, implementar AMP (Accelerated Mobile Pages) puede ayudar a cargar las páginas casi instantáneamente, mejorando la experiencia del usuario en dispositivos móviles.\n\nTambién es importante establecer presupuestos de rendimiento, que son límites en métricas clave de velocidad, y hacer un seguimiento continuo mediante herramientas como Lighthouse, WebPageTest, y Chrome User Experience Report para identificar y solucionar cuellos de botella en el rendimiento.\n\nPor último, mejorar la velocidad no es un esfuerzo único, sino un cambio en el estilo de vida del desarrollo web, que requiere mantener buenas prácticas de optimización de forma constante para asegurar que el sitio siga siendo rápido y eficiente.', 'annotations': [{'file_id': 'file-JpMbqA28K7MSxsgS1VduFC', 'filename': 'Mobile_Site_Speed_Playbook.pdf', 'type': 'file_citation', 'file_index': 435}, {'file_id': 'file-JpMbqA28K7MSxsgS1VduFC', 'filename': 'Mobile_Site_Speed_Playbook.pdf', 'type': 'file_citation', 'file_index': 730}, {'file_id': 'file-JpMbqA28K7MSxsgS1VduFC', 'filename': 'Mobile_Site_Speed_Playbook.pdf', 'type': 'file_citation', 'file_index': 978}], 'id': 'msg_01f2f359b6466553006983a30cb1088194bbebd4fe2b755942'}]

# %%
response = llm_with_tools.invoke("Como estas")
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# [{'type': 'text', 'text': '¡Hola! Estoy bien, gracias. ¿En qué puedo ayudarte hoy?', 'annotations': [], 'id': 'msg_0d64d8df22262fc2006983a5ca0e2c8196a96308e6cb469fee'}]
